# %%
import os
def change_eps(number=0.3):
    PATH = 'agent_code/n_step_sarsa_agent/'
    here = os.getcwd().replace('\\','/')
    target_folder = '/'.join((here,PATH))
    file = '/globals.py'
    with open(target_folder+file, 'r')as f:
        string = f.read().split('\n')
        #print(string)
        for i, s in enumerate(string):
            if 'EPS_START' in s:
                s_new = '= '.join((s.split('=')[0],str(number)))
                string[i] = s_new

    with open(target_folder+file, 'w') as n:
        n.write('\n'.join(string))

change_eps(number=0.7)

# %% [markdown]
# ## Q-Table agent

# %%
from time import sleep

i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents qtable_agent --train 1 --n-rounds 20 --scenario coin5 --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents qtable_agent no_movement_agent no_movement_agent --train 1 --n-rounds 200 --scenario empty --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents qtable_agent peaceful_agent --train 1 --n-rounds 200 --scenario coin5 --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents qtable_agent peaceful_agent --train 1 --n-rounds 200 --scenario crates --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents qtable_agent rule_based_agent --train 1 --n-rounds 200 --scenario classic --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# %% [markdown]
# ## SARSA agent

# %%
from time import sleep

i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents sarsa_agent --train 1 --n-rounds 20 --scenario coin5 --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents sarsa_agent no_movement_agent no_movement_agent --train 1 --n-rounds 200 --scenario empty --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents sarsa_agent peaceful_agent --train 1 --n-rounds 200 --scenario coin5 --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents sarsa_agent peaceful_agent --train 1 --n-rounds 200 --scenario crates --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents qtable_agent rule_based_agent --train 1 --n-rounds 200 --scenario classic --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# %% [markdown]
# ## N step SARSA agent

# %%
from time import sleep

i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents n_step_sarsa_agent --train 1 --n-rounds 20 --scenario coin5 --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents n_step_sarsa_agent no_movement_agent no_movement_agent --train 1 --n-rounds 200 --scenario empty --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents n_step_sarsa_agent peaceful_agent --train 1 --n-rounds 200 --scenario coin5 --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents n_step_sarsa_agent peaceful_agent --train 1 --n-rounds 200 --scenario crates --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1

# save 50 files 
i = 1
EPS_START = 0.3
EPS_END = 0.001
EPS_DECAY = 0.995
EPS = EPS_start
while True:
    #%run  main.py play --agents qtable_agent --train 1 --n-rounds 10 --scenario coin-heaven --no-gui --save-stat
    # %run main.py play --agents n_step_agent rule_based_agent --train 1 --n-rounds 200 --scenario classic --no-gui --save-stats
    if EPS > EPS_END:
        EPS = EPS * EPS_DECAY**10
        change_eps(number=EPS)
    #sleep(1)
    if i==50: break
    i += 1
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  8.85it/s]
# 100%|██████████| 20/20 [00:01<00:00, 11.32it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.38it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.80it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.25it/s]
# 100%|██████████| 20/20 [00:01<00:00, 11.16it/s]
# 100%|██████████| 20/20 [00:01<00:00, 11.94it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.26it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.73it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.42it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.85it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.45it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.90it/s]
# 100%|██████████| 20/20 [00:01<00:00, 11.65it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.46it/s]
# 100%|██████████| 20/20 [00:01<00:00, 11.85it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.51it/s]
# 100%|██████████| 20/20 [00:01<00:00, 11.02it/s]
# 100%|██████████| 20/20 [00:02<00:00,  7.60it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.30it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.03it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.75it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.11it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.70it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.88it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.54it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.53it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.56it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.48it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.98it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.44it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.99it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.24it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.84it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.90it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.64it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.08it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.13it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.09it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.92it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.04it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.90it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.83it/s]
# 100%|██████████| 20/20 [00:02<00:00,  7.96it/s]
# 100%|██████████| 20/20 [00:01<00:00, 10.12it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.46it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.32it/s]
# 100%|██████████| 20/20 [00:02<00:00,  9.06it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.19it/s]
# 100%|██████████| 20/20 [00:02<00:00,  8.56it/s]
# 100%|██████████| 200/200 [00:20<00:00,  9.81it/s]
# 100%|██████████| 200/200 [00:27<00:00,  7.39it/s]
# 100%|██████████| 200/200 [00:29<00:00,  6.73it/s]
# 100%|██████████| 200/200 [00:32<00:00,  6.15it/s]
#  42%|████▎     | 85/200 [00:11<00:16,  7.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Programming/ml_final-project/mle-ss23_final-project/main.py:189
#     183     world_controller(world, args.n_rounds,
#     184                      gui=gui, every_step=every_step, turn_based=args.turn_based,
#     185                      make_video=args.make_video, update_interval=args.update_interval)
#     188 if __name__ == '__main__':
# --> 189     main()
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/main.py:183, in main(argv)
#     181 else:
#     182     gui = None
# --> 183 world_controller(world, args.n_rounds,
#     184                  gui=gui, every_step=every_step, turn_based=args.turn_based,
#     185                  make_video=args.make_video, update_interval=args.update_interval)
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/main.py:71, in world_controller(world, n_rounds, gui, every_step, turn_based, make_video, update_interval)
#      69 # Advances step (for turn based: only if user input is available)
#      70 if world.running and not (turn_based and user_input is None):
# ---> 71     world.do_step(user_input)
#      72     user_input = None
#      73 else:
#      74     # Might want to wait
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/environment.py:224, in GenericWorld.do_step(self, user_input)
#     222 self.update_bombs()
#     223 self.evaluate_explosions()
# --> 224 self.send_game_events()
#     226 if self.time_to_stop():
#     227     self.end_round()
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/environment.py:558, in BombeRLeWorld.send_game_events(self)
#     556 if a.train:
#     557     if not a.dead or a.name == "get_data_agent": # Not a great solution but works
# --> 558         a.wait_for_game_event_processing()
#     559     for enemy in self.active_agents:
#     560         if enemy is not a:
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agents.py:159, in Agent.wait_for_game_event_processing(self)
#     158 def wait_for_game_event_processing(self):
# --> 159     self.backend.get("game_events_occurred")
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agents.py:277, in AgentBackend.get(self, expect_name, block, timeout)
#     276 def get(self, expect_name: str, block=True, timeout=None):
# --> 277     return self.get_with_time(expect_name, block, timeout)[0]
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agents.py:285, in AgentBackend.get_with_time(self, expect_name, block, timeout)
#     283         raise ValueError(f"Logic error: Expected result from event {expect_name}, but found {event_name}")
#     284     if isinstance(result, BaseException):
# --> 285         raise result
#     286     return result, compute_time
#     287 except queue.Empty:
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agents.py:248, in AgentRunner.process_event(self, event_name, *event_args)
#     246 self.wlogger.debug(f"Calling {event_name} on callback.")
#     247 start_time = time()
# --> 248 event_result = getattr(module, event_name)(self.fake_self, *event_args)
#     249 duration = time() - start_time
#     250 self.wlogger.debug(f"Got result from callback#{event_name} in {duration:.3f}s.")
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agent_code/n_step_sarsa_agent/train.py:41, in game_events_occurred(self, old_game_state, self_action, new_game_state, events)
#      38 reward = reward_from_events(self, events)
#      40 # state_to_features is defined in model.py
# ---> 41 old_state_feature = self.MODEL_TYPE.state_to_features(old_game_state, self)
#      42 self.transitions.append(Transition(old_state_feature,
#      43                                     self_action,
#      44                                     self.MODEL_TYPE.state_to_features(new_game_state, self),
#      45                                     reward,
#      46                                     new_game_state))
#      48 # update stats
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agent_code/n_step_sarsa_agent/model.py:314, in NSTEP_SARSA.state_to_features(game_state, agent)
#     310 enemy_feature = torch.tensor(enemy_feature).view(1)
#     312 # Feature: Bomb safety
#     313 # 2^6 = 64 permutations
# --> 314 safety_feature = get_safety_feature((my_x, my_y), field, explosion_map, bombs)
#     316 # Bomb attack feature
#     317
#     318 # Check if agent next to a crate
#     319 adjacent_fields = [(my_x, my_y - 1), (my_x, my_y + 1), (my_x - 1, my_y), (my_x + 1, my_y)]
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agent_code/n_step_sarsa_agent/features.py:200, in get_safety_feature(pos_agent, field, explosion_map, bombs)
#     198     # Update agent position
#     199     new_pos = pos_update(pos_agent, i)
# --> 200     output[i] = int(find_safe_tile(new_pos, new_field, new_explosion_map, new_bombs, 1))
#     202 # Bomb safety
#     203 new_pos = pos_agent
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agent_code/n_step_sarsa_agent/features.py:225, in find_safe_tile(pos_agent, field, explosion_map, bombs, depth)
#     222 # Update field (crates destroyed)
#     223 # Update explosion map (old explosions removed, new explosions added)
#     224 new_explosion_map, new_field, new_bombs = explosion_map_update(explosion_map, bombs, field)
# --> 225 field_feature = get_allowed_actions(pos_agent, field, explosion_map, new_explosion_map, new_bombs)
#     227 # TODO : Explore directions in greedy order?
#     228 for i, direction in enumerate(field_feature):
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agent_code/n_step_sarsa_agent/features.py:279, in get_allowed_actions(my_pos, field, old_explosion_map, new_explosion_map, bombs)
#     276 field = field.copy()
#     277 field[(old_explosion_map + new_explosion_map) > 0] = 5
# --> 279 bombs = [bomb[0] for bomb in bombs]
#     280 # TODO : vectorize
#     281 for b in bombs:
#
# File ~/Programming/ml_final-project/mle-ss23_final-project/agent_code/n_step_sarsa_agent/features.py:279, in <listcomp>(.0)
#     276 field = field.copy()
#     277 field[(old_explosion_map + new_explosion_map) > 0] = 5
# --> 279 bombs = [bomb[0] for bomb in bombs]
#     280 # TODO : vectorize
#     281 for b in bombs:
#
# KeyboardInterrupt:
#  46%|████▋     | 93/200 [00:12<00:12,  8.76it/s]

# %% [markdown]
# ### .json stats

# %%
import os
import json
from matplotlib import pyplot as plt

PATH = 'results'
here = os.getcwd().replace('\\','/')
target_folder = '/'.join((here,PATH))
files = [file for file in os.listdir(target_folder) if file.endswith('.json')]
plot_keys = ['bombs', 'coins', 'crates', 'invalid', 'kills', 'score', 'suicides', 'time']
scores = []
for file in files:
    #print(file)
    file_path = '/'.join((target_folder,file))
    with open(file_path)as f:
        data = json.load(f)
    #print(data)
    agents = data['by_agent']
    agent = agents['qtable_agent']
    score = agent['score']/agent['rounds']
    scores.append(score)
print(scores)
plt.plot(scores)

# %% [markdown]
# ### .pkl stats

# %%
import os
import json
import pickle
from matplotlib import pyplot as plt

PATH = 'agent_code/qtable_agent/stats'
here = os.getcwd().replace('\\','/')
target_folder = '/'.join((here,PATH))
files = [file for file in os.listdir(target_folder) if file.endswith('.pkl')]
plot_keys = ['bombs', 'coins', 'crates', 'invalid', 'kills', 'score', 'suicides', 'time']
scores = []
for file in files:
    #print(file)
    file_path = '/'.join((target_folder,file))
    with open(file_path, "rb")as f:
        stats = pickle.load(f)
    scores += stats.round_score_history
print(scores)
plt.plot(scores)

# %%
agents = data['by_agent']

def performance_plot(agents):
    # TODO : maybe we also want the number of wins
    plot_keys = ['bombs', 'coins', 'crates', 'invalid', 'kills', 'score', 'suicides', 'time']
    fig, axs = plt.subplots(len(plot_keys), sharex=True, figsize=(10,10), layout="constrained")
    fig.suptitle('Statistics',size=13)
    axs = axs.flatten()
    for key, ax in zip(plot_keys, axs):
        ax.set_title(key)
        ax.set_ylabel('score')
        try: 
            for agent_name in agents.keys():
                agent = agents[agent_name]
                stat = agent[key]
                p = ax.bar(agent_name, stat, label=str(stat))
                ax.bar_label(p, label_type="center")
        except:
            continue
    plt.xticks(rotation=45)

performance_plot(agents)
