# %% [markdown]
# <a href="https://colab.research.google.com/github/Schlevidon/mle-ss23_final-project/blob/master/FinalProject_Bomberman_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = 'Schlevidon'
repository = 'mle-ss23_final-project'
git_token = str(input('Github token'))
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Github token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
# fatal: destination path 'mle-ss23_final-project' already exists and is not an empty directory.

# %%
cd mle-ss23_final-project/
# Out:
# /content/mle-ss23_final-project/mle-ss23_final-project

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import sys
drive_path = '/content/gdrive/MyDrive/Colab Notebooks/bomberman_data'
sys.path.append(drive_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Folder for models:
# https://drive.google.com/drive/folders/1yTdNJA_25UTh7LKkZk6FhZ55J-uhlG9F?usp=sharing

# %%
cd Test_Colab
# Out:
# /content/gdrive/.shortcut-targets-by-id/1OPL21xHz2DFR9aYoOGTkjePJOwjwocXl/Test_Colab

# %%
with open(drive_path+'/test.txt','w')as r:
  r.write('hallo')

# %%
#%run main.py play --log-dir logs
# Out:
# INFO:BombeRLeWorld:Initializing game world
# DEBUG:rule_based_agent_0_code:Successfully entered setup code
# DEBUG:rule_based_agent_1_code:Successfully entered setup code
# DEBUG:rule_based_agent_2_code:Successfully entered setup code
# DEBUG:rule_based_agent_3_code:Successfully entered setup code
#   0%|          | 0/10 [00:00<?, ?it/s]INFO:BombeRLeWorld:STARTING ROUND #1
# INFO:BombeRLeWorld:STARTING STEP 1
# INFO:rule_based_agent_0_code:Picking action according to rule set
# DEBUG:rule_based_agent_0_code:Valid actions: ['LEFT', 'DOWN', 'WAIT', 'BOMB']
# DEBUG:rule_based_agent_0_code:Suitable target found at (14, 1)
# INFO:rule_based_agent_1_code:Picking action according to rule set
# DEBUG:rule_based_agent_1_code:Valid actions: ['RIGHT', 'UP', 'WAIT', 'BOMB']
# DEBUG:rule_based_agent_1_code:Suitable target found at (1, 14)
# INFO:rule_based_agent_2_code:Picking action according to rule set
# DEBUG:rule_based_agent_2_code:Valid actions: ['LEFT', 'UP', 'WAIT', 'BOMB']
# ...

# %%
import settings as s
s.SCENARIOS
# Out:
# {'empty': {'CRATE_DENSITY': 0, 'COIN_COUNT': 0},
#  'one-coin': {'CRATE_DENSITY': 0, 'COIN_COUNT': 1},
#  'one-crate': {'CRATE_DENSITY': 0.005649717514124294, 'COIN_COUNT': 1},
#  'coin-heaven': {'CRATE_DENSITY': 0, 'COIN_COUNT': 50},
#  'coin-heaven2': {'CRATE_DENSITY': 0.1, 'COIN_COUNT': 10},
#  'coin-heaven3': {'CRATE_DENSITY': 0, 'COIN_COUNT': 200},
#  'crates': {'CRATE_DENSITY': 0.1, 'COIN_COUNT': 10},
#  'loot-crate': {'CRATE_DENSITY': 0.75, 'COIN_COUNT': 50},
#  'classic': {'CRATE_DENSITY': 0.75, 'COIN_COUNT': 9}}

# %%
i = 1
while True:
    print(f'Round: {i}')
    # %run  main.py play --agents n_step_sarsa_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent rule_based_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent rule_based_agent rule_based_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    i += 1

    if i==3: break
# Out:
# Round: 1
# ...
# 100%|██████████| 500/500 [15:44<00:00,  1.89s/it]
# Round: 2
# ...
# 100%|██████████| 500/500 [06:54<00:00,  1.21it/s]

# %%
i = 1
while True:
    print(f'Round: {i}')
    # %run  main.py play --agents n_step_sarsa_agent no_movement_agent --train 1 --n-rounds 500 --scenario coin5 --no-gui
    # %run  main.py play --agents n_step_sarsa_agent no_movement_agent --train 1 --n-rounds 500 --scenario crates --no-gui

    # %run  main.py play --agents n_step_sarsa_agent peaceful_agent --train 1 --n-rounds 500 --scenario coin5 --no-gui
    # %run  main.py play --agents n_step_sarsa_agent peaceful_agent --train 1 --n-rounds 500 --scenario crates --no-gui

    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent --train 1 --n-rounds 500 --scenario coin5 --no-gui
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent --train 1 --n-rounds 500 --scenario crates --no-gui

    i+=1
# Out:
# Round: 1
# ...
# 100%|██████████| 500/500 [07:32<00:00,  1.11it/s]
# Round: 1
# ...
#  49%|████▉     | 246/500 [04:12<04:20,  1.03s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\User\Documents\Studium\Machine Learning\Machine Learning Essentials\Submissions\Project\git\mle-ss23_final-project\main.py in <module>
#     187
#     188 if __name__ == '__main__':
# --> 189     main()
#
# c:\Users\User\Documents\Studium\Machine Learning\Machine Learning Essentials\Submissions\Project\git\mle-ss23_final-project\main.py in main(argv)
#     181     else:
#     182         gui = None
# --> 183     world_controller(world, args.n_rounds,
#     184                      gui=gui, every_step=every_step, turn_based=args.turn_based,
#     185                      make_video=args.make_video, update_interval=args.update_interval)
#
# ...

# %%
i = 1
while True:
    print(f'Round: {i}')
    # Coins
    # no enemy
    #if i !=1:
    # %run  main.py play --agents n_step_sarsa_agent --train 1 --n-rounds 500 --scenario coin5 --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent no_movement_agent --train 1 --n-rounds 500 --scenario coin5 --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent coin_collector_agent --train 1 --n-rounds 500 --scenario coin5 --no-gui
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent --train 1 --n-rounds 500 --scenario coin5 --no-gui 
    

    # %run  main.py play --agents n_step_sarsa_agent --train 1 --n-rounds 500 --scenario loot-crate --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent no_movement_agent --train 1 --n-rounds 500 --scenario loot-crate --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent coin_collector_agent --train 1 --n-rounds 500 --scenario loot-crate --no-gui
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent --train 1 --n-rounds 500 --scenario loot-crate --no-gui

    # %run  main.py play --agents n_step_sarsa_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent no_movement_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent coin_collector_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent rule_based_agent --train 1 --n-rounds 500 --scenario classic --no-gui 
    # %run  main.py play --agents n_step_sarsa_agent rule_based_agent rule_based_agent rule_based_agent --train 1 --n-rounds 500 --scenario classic --no-gui 

    i += 1
# Out:
# Round: 1
# ...
#  59%|█████▊    | 293/500 [03:26<02:26,  1.42it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\User\Documents\Studium\Machine Learning\Machine Learning Essentials\Submissions\Project\git\mle-ss23_final-project\main.py in <module>
#     187
#     188 if __name__ == '__main__':
# --> 189     main()
#
# c:\Users\User\Documents\Studium\Machine Learning\Machine Learning Essentials\Submissions\Project\git\mle-ss23_final-project\main.py in main(argv)
#     181     else:
#     182         gui = None
# --> 183     world_controller(world, args.n_rounds,
#     184                      gui=gui, every_step=every_step, turn_based=args.turn_based,
#     185                      make_video=args.make_video, update_interval=args.update_interval)
#
# ...

# %%
#for scenario in [s.SCENARIOS]:
while True:
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent peaceful_agent peaceful_agent --train 2 --n-rounds 1000 --scenario coin-heaven --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent peaceful_agent peaceful_agent --train 2 --n-rounds 5000 --scenario crates --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent peaceful_agent peaceful_agent --train 2 --n-rounds 5000 --scenario classic --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent peaceful_agent peaceful_agent --train 2 --n-rounds 5000 --scenario loot-crate --no-gui

    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent rule_based_agent --train 1 --n-rounds 1000 --scenario coin-heaven --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent rule_based_agent --train 1 --n-rounds 1000 --scenario crates --no-gui

    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent peaceful_agent --train 2 --n-rounds 1000 --scenario coin-heaven --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent peaceful_agent --train 2 --n-rounds 5000 --scenario crates --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent peaceful_agent --train 2 --n-rounds 5000 --scenario classic --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent peaceful_agent --train 2 --n-rounds 5000 --scenario loot-crate --no-gui

    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent rule_based_agent --train 2 --n-rounds 1000 --scenario coin-heaven --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent rule_based_agent --train 2 --n-rounds 5000 --scenario crates --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent rule_based_agent --train 2 --n-rounds 5000 --scenario classic --no-gui
    # %run  main.py play --agents n_step_sarsa_agent n_step_sarsa_agent rule_based_agent rule_based_agent --train 2 --n-rounds 5000 --scenario loot-crate --no-gui
# Out:
# ...
#  24%|██▍       | 1205/5000 [3:37:29<11:24:56, 10.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\User\Documents\Studium\Machine Learning\Machine Learning Essentials\Submissions\Project\git\mle-ss23_final-project\main.py in <module>
#     187
#     188 if __name__ == '__main__':
# --> 189     main()
#
# c:\Users\User\Documents\Studium\Machine Learning\Machine Learning Essentials\Submissions\Project\git\mle-ss23_final-project\main.py in main(argv)
#     181     else:
#     182         gui = None
# --> 183     world_controller(world, args.n_rounds,
#     184                      gui=gui, every_step=every_step, turn_based=args.turn_based,
#     185                      make_video=args.make_video, update_interval=args.update_interval)
#
# ...
