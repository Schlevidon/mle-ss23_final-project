# %% [markdown]
# <a href="https://colab.research.google.com/github/Schlevidon/mle-ss23_final-project/blob/master/FinalProject_Bomberman_git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = 'Schlevidon'
repository = 'mle-ss23_final-project'
git_token = str(input('Github token'))
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Github token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
# fatal: destination path 'mle-ss23_final-project' already exists and is not an empty directory.

# %%
cd mle-ss23_final-project/
# Out:
# /content/mle-ss23_final-project/mle-ss23_final-project

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import sys
drive_path = '/content/gdrive/MyDrive/Colab Notebooks/bomberman_data'
sys.path.append(drive_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Folder for models:
# https://drive.google.com/drive/folders/1yTdNJA_25UTh7LKkZk6FhZ55J-uhlG9F?usp=sharing

# %%
cd Test_Colab
# Out:
# /content/gdrive/.shortcut-targets-by-id/1OPL21xHz2DFR9aYoOGTkjePJOwjwocXl/Test_Colab

# %%
with open(drive_path+'/test.txt','w')as r:
  r.write('hallo')

# %%
#%run main.py play --log-dir logs
# Out:
# INFO:BombeRLeWorld:Initializing game world
# DEBUG:rule_based_agent_0_code:Successfully entered setup code
# DEBUG:rule_based_agent_1_code:Successfully entered setup code
# DEBUG:rule_based_agent_2_code:Successfully entered setup code
# DEBUG:rule_based_agent_3_code:Successfully entered setup code
#   0%|          | 0/10 [00:00<?, ?it/s]INFO:BombeRLeWorld:STARTING ROUND #1
# INFO:BombeRLeWorld:STARTING STEP 1
# INFO:rule_based_agent_0_code:Picking action according to rule set
# DEBUG:rule_based_agent_0_code:Valid actions: ['LEFT', 'DOWN', 'WAIT', 'BOMB']
# DEBUG:rule_based_agent_0_code:Suitable target found at (14, 1)
# INFO:rule_based_agent_1_code:Picking action according to rule set
# DEBUG:rule_based_agent_1_code:Valid actions: ['RIGHT', 'UP', 'WAIT', 'BOMB']
# DEBUG:rule_based_agent_1_code:Suitable target found at (1, 14)
# INFO:rule_based_agent_2_code:Picking action according to rule set
# DEBUG:rule_based_agent_2_code:Valid actions: ['LEFT', 'UP', 'WAIT', 'BOMB']
# ...
